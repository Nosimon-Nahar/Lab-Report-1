# %% [markdown]
# <a href="https://colab.research.google.com/github/Nosimon-Nahar/Lab-Report-1/blob/main/ReflectionXYaxis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/cat.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
#Reflection about X axis
reflectedX = cv2.flip(image, 0)
#Reflection about Y axis
reflectedY = cv2.flip(image, 1)

# %%
plt.figure(figsize=(40,37))

# %%
plt.subplot(2,3,(1,3))
plt.imshow(image)
plt.title('Original image')
plt.axis('off')

plt.subplot(2,3,4)
plt.imshow(reflectedX)
plt.title('Reflection about X axis')
plt.axis('off')

plt.subplot(2,3,6)
plt.imshow(reflectedY)
plt.title('Reflection about Y axis')
plt.axis('off')

plt.show()
