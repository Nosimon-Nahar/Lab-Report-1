# %% [markdown]
# <a href="https://colab.research.google.com/github/Nosimon-Nahar/Lab-Report-1/blob/main/Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/cat.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# image dimension
h, w = image.shape[:2] # (height, width), channel

# %%
#scaling factors
sx = 5
sy = 3

# %%
#scaling matrix
M = np.float32([
    [sx, 0, 0],
    [0, sy, 0]
])

# %%
scaledImage= cv2.warpAffine(image, M, (int(w*sx),int(h*sy)))

# %%
plt.figure(figsize=(10,5))

# %%
plt.subplot(1,2,1)
plt.imshow(image)
plt.title('Original image')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(scaledImage)
plt.title('Scaled image')
plt.axis('off')

plt.show()
